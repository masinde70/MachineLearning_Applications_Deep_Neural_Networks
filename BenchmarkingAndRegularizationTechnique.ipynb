# %% [markdown]
# Benchmarking Regularization Techniques
# Quite a few hyperparameters have been introduced so far. Tweaking each of these values can have an effect on the score obtained by your neural networks. Some of the hyperparameters seen so far include:
#
# * Number of layers in the neural network
# * How many neurons in each layer
# * What activation functions to use on each layer
# * Dropout percent on each layer
# * L1 and L2 values on each layer
#
# To try out each of these hyperparameters you will need to run train neural networks with multiple settings for each hyperparameter. However, you may have noticed that neural networks often produce somewhat different results when trained multiple times. This is because the neural networks start with random weights. Because of this it is necessary to fit and evaluate a neural network times to ensure that one set of hyperparameters are actually better than another. Bootstrapping can be an effective means of benchmarking (comparing) two sets of hyperparameters.
#
# Bootstrapping is similar to cross-validation. Both go through a number of cycles/folds providing validation and training sets. However, bootstrapping can have an unlimited number of cycles. Bootstrapping chooses a new train and validation split each cycle, with replacement. The fact that each cycle is chosen with replacement means that, unlike cross validation, there will often be repeated rows selected between cycles. If you run the bootstrap for enough cycles, there will be duplicate cycles.
#
# In this part we will use bootstrapping for hyperparameter benchmarking. We will train a neural network for a specified number of splits (denoted by the SPLITS constant). For these examples we use 100. We will compare the average score at the end of the 100. By the end of the cycles the mean score will have converged somewhat. This ending score will be a much better basis of comparison than a single cross-validation. Additionally, the average number of epochs will be tracked to give an idea of a possible optimal value. Because the early stopping validation set is also used to evaluate the the neural network as well, it might be slightly inflated. This is because we are both stopping and evaluating on the same sample. However, we are using the scores only as relative measures to determine the superiority of one set of hyperparameters to another, so this slight inflation should not present too much of a problem.
#
# Because we are benchmarking, we will display the amount of time taken for each cycle. The following function can be used to nicely format a time span.

# %%
# Nicely formated time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int (sec_elapsed % (60 * 60))
    s = sec_elapsed % 60
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %% [markdown]
# # Bootstrapping for Regression
# Regression bootstrapping uses the ShuffleSplit object to perform the splits. This is similar to KFold for cross validation, no balancing takes place. To demonstrate this technique we will attempt to predict the age column for the jh-simple-dataset this data is loaded by the following code.

# %%
import pandas as pd
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
import os
import time

start_time = time.time()
# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])

# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'], prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

#Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],axis=1)
df.drop('area', axis=1, inplace=True)

#Generate dummies for product
df = pd.concat([df,pd.get_dummies(df['product'],prefix="product")],axis=1)
df.drop('product', axis=1, inplace=True)

#Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)


#Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['subscriptions'] = zscore(df['subscriptions'])

#Convert to numpy -Classification
x_columns = df.columns.drop('age').drop('id')
x = df[x_columns].values
y = df['age'].values

# %% [markdown]
# The following code performs the bootstrap. The architecture of the neural network can be adjusted to compare many different configurations.

# %%
import pandas as pd
import os
import numpy as np
import time
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import ShuffleSplit

SPLITS = 50

# Bootstrap
boot = ShuffleSplit(n_splits=SPLITS, test_size=0.1, random_state=42)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x):
    start_time = time.time()
    num+=1
    
    #Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]
    
    #Construct neural network
    model = Sequential()
    model.add(Dense(20, input_dim=x_train.shape[1], activation='relu'))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3,
                           patience=5, verbose=0, mode='auto', restore_best_weights=True)
    
    # Train on the bootstrap sample
    model.fit(x_train, y_train,validation_data=(x_test,y_test),
             callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    #predict
    pred = model.predict(x_test)
    
    #Measure this bootstrap's log loss
    score = np.sqrt(metrics.mean_squared_error(pred,y_test))
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"{num}: score={score:.6f},mean score={m1:.6f},stdev={mdev:.6f},epochs={epochs},mean epochs={int(m2)},time={hms_string(time_took)}")
# Out:
# 1: score=0.749195,mean score=0.749195,stdev=0.000000,epochs=129,mean epochs=129,time=0:15:15.90
# 2: score=0.908850,mean score=0.829023,stdev=0.079828,epochs=109,mean epochs=119,time=0:11:11.71
# 3: score=0.543559,mean score=0.733868,stdev=0.149523,epochs=115,mean epochs=117,time=0:12:12.23
# 4: score=0.731385,mean score=0.733247,stdev=0.129495,epochs=135,mean epochs=122,time=0:14:14.40
# 5: score=0.768235,mean score=0.740245,stdev=0.116666,epochs=115,mean epochs=120,time=0:12:12.23
# 6: score=0.782542,mean score=0.747294,stdev=0.107661,epochs=172,mean epochs=129,time=0:18:18.26
# 7: score=0.548854,mean score=0.718946,stdev=0.121478,epochs=138,mean epochs=130,time=0:14:14.68
# 8: score=0.638537,mean score=0.708895,stdev=0.116703,epochs=106,mean epochs=127,time=0:11:11.43
# 9: score=0.629531,mean score=0.700077,stdev=0.112820,epochs=106,mean epochs=125,time=0:11:11.38
# 10: score=1.169910,mean score=0.747060,stdev=0.176981,epochs=95,mean epochs=122,time=0:10:10.18
# 11: score=1.110526,mean score=0.780102,stdev=0.198476,epochs=97,mean epochs=119,time=0:10:10.36
# 12: score=0.767721,mean score=0.779071,stdev=0.190058,epochs=113,mean epochs=119,time=0:12:12.03
# 13: score=0.760554,mean score=0.777646,stdev=0.182668,epochs=100,mean epochs=117,time=0:10:10.81
# 14: score=0.919126,mean score=0.787752,stdev=0.179755,epochs=97,mean epochs=116,time=0:10:10.46
# 15: score=0.572095,mean score=0.773375,stdev=0.181801,epochs=126,mean epochs=116,time=0:13:13.56
# 16: score=0.789717,mean score=0.774396,stdev=0.176072,epochs=100,mean epochs=115,time=0:10:10.79
# 17: score=0.816854,mean score=0.776894,stdev=0.171107,epochs=121,mean epochs=116,time=0:12:12.89
# 18: score=0.949608,mean score=0.786489,stdev=0.170928,epochs=107,mean epochs=115,time=0:11:11.46
# 19: score=0.675211,mean score=0.780632,stdev=0.168214,epochs=106,mean epochs=115,time=0:11:11.38
# 20: score=0.897824,mean score=0.786492,stdev=0.165932,epochs=131,mean epochs=115,time=0:13:13.84
# 21: score=0.922553,mean score=0.792971,stdev=0.164505,epochs=91,mean epochs=114,time=0:09:09.80
# 22: score=0.558954,mean score=0.782334,stdev=0.167953,epochs=124,mean epochs=115,time=0:13:13.22
# 23: score=0.674764,mean score=0.777657,stdev=0.165719,epochs=104,mean epochs=114,time=0:11:11.38
# 24: score=0.578826,mean score=0.769372,stdev=0.167024,epochs=140,mean epochs=115,time=0:14:14.94
# 25: score=0.637802,mean score=0.764109,stdev=0.165668,epochs=116,mean epochs=115,time=0:12:12.27
# 26: score=0.693390,mean score=0.761389,stdev=0.163019,epochs=113,mean epochs=115,time=0:11:11.98
# 27: score=0.610718,mean score=0.755809,stdev=0.162483,epochs=102,mean epochs=115,time=0:11:11.04
# 28: score=0.840778,mean score=0.758844,stdev=0.160332,epochs=100,mean epochs=114,time=0:10:10.87
# 29: score=0.520014,mean score=0.750608,stdev=0.163460,epochs=121,mean epochs=114,time=0:12:12.92
# 30: score=0.587812,mean score=0.745182,stdev=0.163348,epochs=136,mean epochs=115,time=0:14:14.39
# 31: score=0.581989,mean score=0.739917,stdev=0.163258,epochs=159,mean epochs=116,time=0:16:16.92
# 32: score=0.535574,mean score=0.733532,stdev=0.164573,epochs=109,mean epochs=116,time=0:11:11.75
# 33: score=0.547689,mean score=0.727900,stdev=0.165162,epochs=139,mean epochs=117,time=0:14:14.75
# 34: score=3.675070,mean score=0.814581,stdev=0.523858,epochs=937,mean epochs=141,time=0:97:37.72
# 35: score=0.590533,mean score=0.808180,stdev=0.517668,epochs=120,mean epochs=140,time=0:12:12.88
# 36: score=0.566864,mean score=0.801477,stdev=0.511965,epochs=151,mean epochs=141,time=0:16:16.02
# 37: score=1.205266,mean score=0.812390,stdev=0.509227,epochs=93,mean epochs=139,time=0:10:10.12
# 38: score=0.722978,mean score=0.810037,stdev=0.502686,epochs=102,mean epochs=138,time=0:10:10.98
# 39: score=0.511218,mean score=0.802375,stdev=0.498442,epochs=112,mean epochs=138,time=0:12:12.14
# 40: score=0.710768,mean score=0.800085,stdev=0.492380,epochs=151,mean epochs=138,time=0:16:16.18
# 41: score=1.275464,mean score=0.811680,stdev=0.491836,epochs=83,mean epochs=137,time=0:08:08.99
# 42: score=0.698335,mean score=0.808981,stdev=0.486252,epochs=97,mean epochs=136,time=0:10:10.45
# 43: score=0.670068,mean score=0.805750,stdev=0.481021,epochs=155,mean epochs=136,time=0:16:16.32
# 44: score=0.705213,mean score=0.803465,stdev=0.475759,epochs=111,mean epochs=136,time=0:11:11.87
# 45: score=1.095437,mean score=0.809954,stdev=0.472408,epochs=100,mean epochs=135,time=0:10:10.75
# 46: score=0.541980,mean score=0.804128,stdev=0.468876,epochs=107,mean epochs=134,time=0:11:11.78
# 47: score=0.597551,mean score=0.799733,stdev=0.464818,epochs=120,mean epochs=134,time=0:12:12.88
# 48: score=0.879516,mean score=0.801395,stdev=0.460092,epochs=105,mean epochs=133,time=0:11:11.51
# 49: score=0.859529,mean score=0.802581,stdev=0.455447,epochs=146,mean epochs=133,time=0:15:15.63
# 50: score=0.652162,mean score=0.799573,stdev=0.451361,epochs=130,mean epochs=133,time=0:13:13.78

# %% [markdown]
# The bootstrapping process for classification is similar and is presented in the next section.

# %% [markdown]
# ## Bootstrapping for Classification
#
# Regression bootstrapping uses the  *StratifiedShuffleSplit*  object to perform the splits. This is similar to *StratifiedKFold*  for cross validation, as the classes are balanced so that the sampling has no effect on proportions. To demonstrate this technique we will attempt to predict the product column for the jh-simple-dataset this data is loaded by the following code.

# %%
import pandas as pd
from scipy.stats import zscore

# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])

# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'],prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],axis=1)
df.drop('area', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['age'] = zscore(df['age'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('product').drop('id')
x = df[x_columns].values
dummies = pd.get_dummies(df['product']) # Classification
products = dummies.columns
y = dummies.values

# %%
import os
import numpy as np
import time
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedShuffleSplit

SPLITS = 50

# Bootstrap
boot = StratifiedShuffleSplit(n_splits=SPLITS, test_size=0.1, 
                                random_state=42)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x,df['product']):
    start_time = time.time()
    num+=1

    # Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]

    # Construct neural network
    model = Sequential()
    model.add(Dense(50, input_dim=x.shape[1], activation='relu')) # Hidden 1
    model.add(Dense(25, activation='relu')) # Hidden 2
    model.add(Dense(y.shape[1],activation='softmax')) # Output
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=25, verbose=0, mode='auto', restore_best_weights=True)
    
    # Train on the bootstrap sample
    model.fit(x_train,y_train,validation_data=(x_test,y_test),
              callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    # Predict on the out of boot (validation)
    pred = model.predict(x_test)
  
    # Measure this bootstrap's log loss
    y_compare = np.argmax(y_test,axis=1) # For log loss calculation
    score = metrics.log_loss(y_compare, pred)
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"#{num}: score={score:.6f}, mean score={m1:.6f}," +\
          f"stdev={mdev:.6f}, epochs={epochs}, mean epochs={int(m2)}," +\
          f" time={hms_string(time_took)}")
# Out:
# #1: score=0.700584, mean score=0.700584,stdev=0.000000, epochs=65, mean epochs=65, time=0:07:07.80
# #2: score=0.668703, mean score=0.684644,stdev=0.015941, epochs=57, mean epochs=61, time=0:06:06.91
# #3: score=0.671223, mean score=0.680170,stdev=0.014472, epochs=50, mean epochs=57, time=0:06:06.11
# #4: score=0.638795, mean score=0.669826,stdev=0.021864, epochs=119, mean epochs=72, time=0:13:13.97
# #5: score=0.630965, mean score=0.662054,stdev=0.024981, epochs=78, mean epochs=73, time=0:09:09.38
# #6: score=0.710793, mean score=0.670177,stdev=0.029155, epochs=68, mean epochs=72, time=0:08:08.12
# #7: score=0.740103, mean score=0.680167,stdev=0.036432, epochs=41, mean epochs=68, time=0:05:05.06
# #8: score=0.739089, mean score=0.687532,stdev=0.039257, epochs=50, mean epochs=66, time=0:06:06.13
# #9: score=0.628604, mean score=0.680984,stdev=0.041386, epochs=74, mean epochs=66, time=0:08:08.88
# #10: score=0.665996, mean score=0.679486,stdev=0.039519, epochs=69, mean epochs=67, time=0:08:08.25
# #11: score=0.699330, mean score=0.681290,stdev=0.038110, epochs=70, mean epochs=67, time=0:08:08.32
# #12: score=0.720137, mean score=0.684527,stdev=0.038034, epochs=50, mean epochs=65, time=0:06:06.20
# #13: score=0.715711, mean score=0.686926,stdev=0.037475, epochs=65, mean epochs=65, time=0:07:07.98
# #14: score=0.689563, mean score=0.687114,stdev=0.036118, epochs=86, mean epochs=67, time=0:10:10.24
# #15: score=0.655504, mean score=0.685007,stdev=0.035773, epochs=71, mean epochs=67, time=0:08:08.52
# #16: score=0.732785, mean score=0.687993,stdev=0.036517, epochs=51, mean epochs=66, time=0:06:06.21
# #17: score=0.656067, mean score=0.686115,stdev=0.036214, epochs=56, mean epochs=65, time=0:06:06.80
# #18: score=0.679270, mean score=0.685735,stdev=0.035229, epochs=51, mean epochs=65, time=0:06:06.18
# #19: score=0.589875, mean score=0.680689,stdev=0.040422, epochs=67, mean epochs=65, time=0:08:08.03
# #20: score=0.694635, mean score=0.681387,stdev=0.039516, epochs=46, mean epochs=64, time=0:05:05.63
# #21: score=0.659037, mean score=0.680322,stdev=0.038856, epochs=47, mean epochs=63, time=0:05:05.97
# #22: score=0.744177, mean score=0.683225,stdev=0.040225, epochs=58, mean epochs=63, time=0:07:07.13
# #23: score=0.605078, mean score=0.679827,stdev=0.042446, epochs=67, mean epochs=63, time=0:08:08.05
# #24: score=0.737369, mean score=0.682225,stdev=0.043114, epochs=43, mean epochs=62, time=0:05:05.34
# #25: score=0.593054, mean score=0.678658,stdev=0.045715, epochs=58, mean epochs=62, time=0:07:07.01
# #26: score=0.639394, mean score=0.677148,stdev=0.045458, epochs=61, mean epochs=62, time=0:07:07.32
# #27: score=0.726407, mean score=0.678972,stdev=0.045568, epochs=71, mean epochs=62, time=0:08:08.43
# #28: score=0.712511, mean score=0.680170,stdev=0.045178, epochs=65, mean epochs=62, time=0:07:07.83
# #29: score=0.662575, mean score=0.679563,stdev=0.044508, epochs=55, mean epochs=62, time=0:06:06.81
# #30: score=0.695866, mean score=0.680107,stdev=0.043858, epochs=71, mean epochs=62, time=0:08:08.57
# #31: score=0.741110, mean score=0.682075,stdev=0.044470, epochs=41, mean epochs=61, time=0:05:05.14
# #32: score=0.662209, mean score=0.681454,stdev=0.043906, epochs=97, mean epochs=63, time=0:11:11.47
# #33: score=0.621657, mean score=0.679642,stdev=0.044434, epochs=55, mean epochs=62, time=0:06:06.66
# #34: score=0.587111, mean score=0.676920,stdev=0.046484, epochs=69, mean epochs=63, time=0:08:08.25
# #35: score=0.497488, mean score=0.671794,stdev=0.054705, epochs=90, mean epochs=63, time=0:10:10.58
# #36: score=0.647996, mean score=0.671133,stdev=0.054081, epochs=55, mean epochs=63, time=0:06:06.66
# #37: score=0.714019, mean score=0.672292,stdev=0.053797, epochs=62, mean epochs=63, time=0:07:07.44
# #38: score=0.715049, mean score=0.673417,stdev=0.053524, epochs=60, mean epochs=63, time=0:07:07.55
# #39: score=0.768019, mean score=0.675843,stdev=0.054908, epochs=52, mean epochs=63, time=0:06:06.34
# #40: score=0.711466, mean score=0.676733,stdev=0.054502, epochs=46, mean epochs=62, time=0:05:05.63
# #41: score=0.735442, mean score=0.678165,stdev=0.054590, epochs=65, mean epochs=62, time=0:07:07.74
# #42: score=0.636012, mean score=0.677161,stdev=0.054318, epochs=66, mean epochs=62, time=0:07:07.95
# #43: score=0.688340, mean score=0.677421,stdev=0.053709, epochs=61, mean epochs=62, time=0:07:07.33
# #44: score=0.775993, mean score=0.679662,stdev=0.055090, epochs=54, mean epochs=62, time=0:06:06.55
# #45: score=0.629571, mean score=0.678549,stdev=0.054972, epochs=70, mean epochs=62, time=0:08:08.32
# #46: score=0.655569, mean score=0.678049,stdev=0.054475, epochs=46, mean epochs=62, time=0:05:05.87
# #47: score=0.685316, mean score=0.678204,stdev=0.053902, epochs=57, mean epochs=62, time=0:06:06.99
# #48: score=0.752628, mean score=0.679754,stdev=0.054387, epochs=53, mean epochs=62, time=0:06:06.43
# #49: score=0.653953, mean score=0.679228,stdev=0.053952, epochs=92, mean epochs=62, time=0:10:10.80
# #50: score=0.689057, mean score=0.679424,stdev=0.053428, epochs=58, mean epochs=62, time=0:07:07.05

# %% [markdown]
# # Benchmarking
# Now that we've seen how to bootstrap with both classification and regression we can start to try to optimize the hyperparameters for the jh-simple-dataset data. For this example we will encode for classification of the product column. Evaluation will be in log loss.

# %%
import pandas as pd
from scipy.stats import zscore

# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])
# generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'], prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],
               axis=1)
df.drop('area', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['age'] = zscore(df['age'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('product').drop('id')
x = df[x_columns].values
dummies = pd.get_dummies(df['product']) # Classification
products = dummies.columns
y = dummies.values

# %%
import  pandas as pd
import os
import numpy as np
import time
import tensorflow.keras.initializers
import statistics
from sklearn import metrics
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras.layers import LeakyReLU, PReLU, Dense, Activation, Dropout

SPLITS = 100


# Bootstrap
boot = StratifiedShuffleSplit(n_splits=SPLITS, test_size=0.1)

# Track progress
mean_benchmark = []
epochs_needed = []
num = 0

# Loop through samples
for train, test in boot.split(x,df['product']):
    start_time = time.time()
    num+=1
    
    # Split train and test
    x_train = x[train]
    y_train = y[train]
    x_test = x[test]
    y_test = y[test]
    
    # Construct neural network
    model = Sequential()
    model.add(Dense(100, input_dim=x.shape[1], activation=PReLU(), \
        kernel_regularizer=regularizers.l2(1e-4))) # Hidden 1
    model.add(Dropout(0.5))
    model.add(Dense(100, activation=PReLU(), \
        activity_regularizer=regularizers.l2(1e-4))) # Hidden 2
    model.add(Dropout(0.5))
    model.add(Dense(100, activation=PReLU(), \
        activity_regularizer=regularizers.l2(1e-4)
    )) # Hidden 3
#    model.add(Dropout(0.5)) - Usually better performance 
# without dropout on final layer
    model.add(Dense(y.shape[1],activation='softmax')) # Output
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=100, verbose=0, mode='auto', restore_best_weights=True)

    # Train on the bootstrap sample
    model.fit(x_train,y_train,validation_data=(x_test,y_test), \
              callbacks=[monitor],verbose=0,epochs=1000)
    epochs = monitor.stopped_epoch
    epochs_needed.append(epochs)
    
    # Predict on the out of boot (validation)
    pred = model.predict(x_test)
  
    # Measure this bootstrap's log loss
    y_compare = np.argmax(y_test,axis=1) # For log loss calculation
    score = metrics.log_loss(y_compare, pred)
    mean_benchmark.append(score)
    m1 = statistics.mean(mean_benchmark)
    m2 = statistics.mean(epochs_needed)
    mdev = statistics.pstdev(mean_benchmark)
    
    # Record this iteration
    time_took = time.time() - start_time
    print(f"#{num}: score={score:.6f},mean score{m1:.6f},stdev={mdev:.6f},epochs={epochs}, mean epochs={int(m2)},time={hms_string(time_took)}")
# Out:
# #1: score=0.634329,mean score0.634329,stdev=0.000000,epochs=180, mean epochs=180,time=0:31:31.50
# #2: score=0.671775,mean score0.653052,stdev=0.018723,epochs=153, mean epochs=166,time=0:26:26.72
# #3: score=0.681500,mean score0.662535,stdev=0.020336,epochs=135, mean epochs=156,time=0:24:24.31
# #4: score=0.630569,mean score0.654543,stdev=0.022399,epochs=209, mean epochs=169,time=0:36:36.59
# #5: score=0.627776,mean score0.649190,stdev=0.022716,epochs=236, mean epochs=182,time=0:41:41.06
# #6: score=0.765292,mean score0.668540,stdev=0.047981,epochs=147, mean epochs=176,time=0:25:25.69
# #7: score=0.755685,mean score0.680990,stdev=0.053882,epochs=147, mean epochs=172,time=0:25:25.96
# #8: score=0.653674,mean score0.677575,stdev=0.051205,epochs=209, mean epochs=177,time=0:36:36.82
# #9: score=0.670722,mean score0.676814,stdev=0.048324,epochs=220, mean epochs=181,time=0:38:38.60
# #10: score=0.713250,mean score0.680457,stdev=0.047130,epochs=180, mean epochs=181,time=0:31:31.39
# #11: score=0.604052,mean score0.673511,stdev=0.050017,epochs=188, mean epochs=182,time=0:32:32.72
# #12: score=0.578307,mean score0.665578,stdev=0.054641,epochs=201, mean epochs=183,time=0:35:35.55
# #13: score=0.695750,mean score0.667899,stdev=0.053109,epochs=189, mean epochs=184,time=0:33:33.38
# #14: score=0.688482,mean score0.669369,stdev=0.051451,epochs=160, mean epochs=182,time=0:28:28.52
# #15: score=0.652794,mean score0.668264,stdev=0.049878,epochs=155, mean epochs=180,time=0:27:27.18
# #16: score=0.606705,mean score0.664416,stdev=0.050541,epochs=234, mean epochs=183,time=0:40:40.57
# #17: score=0.742016,mean score0.668981,stdev=0.052321,epochs=167, mean epochs=182,time=0:29:29.30
# #18: score=0.665426,mean score0.668784,stdev=0.050854,epochs=154, mean epochs=181,time=0:27:27.44
# #19: score=0.629452,mean score0.666714,stdev=0.050271,epochs=246, mean epochs=184,time=0:42:42.98
# #20: score=0.636835,mean score0.665220,stdev=0.049429,epochs=289, mean epochs=189,time=0:49:49.79
# #21: score=0.719442,mean score0.667802,stdev=0.049600,epochs=122, mean epochs=186,time=0:21:21.47
# #22: score=0.666759,mean score0.667754,stdev=0.048460,epochs=211, mean epochs=187,time=0:36:36.57
# #23: score=0.578120,mean score0.663857,stdev=0.050798,epochs=214, mean epochs=188,time=0:37:37.78
# #24: score=0.696599,mean score0.665221,stdev=0.050157,epochs=143, mean epochs=187,time=0:25:25.39
# #25: score=0.601789,mean score0.662684,stdev=0.050691,epochs=161, mean epochs=186,time=0:28:28.29
# #26: score=0.607612,mean score0.660566,stdev=0.050822,epochs=236, mean epochs=187,time=0:41:41.37
# #27: score=0.718676,mean score0.662718,stdev=0.051066,epochs=163, mean epochs=187,time=0:28:28.51
# #28: score=0.693368,mean score0.663813,stdev=0.050467,epochs=155, mean epochs=185,time=0:27:27.62
# #29: score=0.678244,mean score0.664310,stdev=0.049659,epochs=221, mean epochs=187,time=0:38:38.70
# #30: score=0.647102,mean score0.663737,stdev=0.048922,epochs=184, mean epochs=186,time=0:32:32.51
# #31: score=0.620242,mean score0.662334,stdev=0.048736,epochs=225, mean epochs=188,time=0:39:39.16
# #32: score=0.730069,mean score0.664450,stdev=0.049395,epochs=135, mean epochs=186,time=0:24:24.03
# #33: score=0.684688,mean score0.665064,stdev=0.048765,epochs=159, mean epochs=185,time=0:28:28.04
# #34: score=0.599796,mean score0.663144,stdev=0.049291,epochs=173, mean epochs=185,time=0:30:30.69
# #35: score=0.675924,mean score0.663509,stdev=0.048629,epochs=161, mean epochs=184,time=0:28:28.78
# #36: score=0.597755,mean score0.661683,stdev=0.049151,epochs=225, mean epochs=185,time=0:39:39.05
# #37: score=0.619061,mean score0.660531,stdev=0.048973,epochs=191, mean epochs=185,time=0:33:33.25
# #38: score=0.678693,mean score0.661009,stdev=0.048411,epochs=137, mean epochs=184,time=0:24:24.42
# #39: score=0.579725,mean score0.658924,stdev=0.049484,epochs=309, mean epochs=187,time=0:53:53.01
# #40: score=0.767876,mean score0.661648,stdev=0.051737,epochs=186, mean epochs=187,time=0:33:33.12
# #41: score=0.680481,mean score0.662108,stdev=0.051185,epochs=196, mean epochs=187,time=0:34:34.37
# #42: score=0.603505,mean score0.660712,stdev=0.051355,epochs=262, mean epochs=189,time=0:45:45.46
# #43: score=0.722846,mean score0.662157,stdev=0.051611,epochs=259, mean epochs=191,time=0:44:44.82
# #44: score=0.613626,mean score0.661054,stdev=0.051531,epochs=257, mean epochs=192,time=0:44:44.45
# #45: score=0.635196,mean score0.660480,stdev=0.051098,epochs=193, mean epochs=192,time=0:33:33.63
# #46: score=0.653662,mean score0.660331,stdev=0.050549,epochs=205, mean epochs=193,time=0:36:36.34
# #47: score=0.551831,mean score0.658023,stdev=0.052402,epochs=308, mean epochs=195,time=0:54:54.60
# #48: score=0.647668,mean score0.657807,stdev=0.051875,epochs=207, mean epochs=195,time=0:37:37.88
# #49: score=0.706516,mean score0.658801,stdev=0.051803,epochs=193, mean epochs=195,time=0:39:39.87
# #50: score=0.647214,mean score0.658569,stdev=0.051308,epochs=220, mean epochs=196,time=0:39:39.44
# #51: score=0.578949,mean score0.657008,stdev=0.051988,epochs=288, mean epochs=198,time=0:50:50.71
# #52: score=0.775909,mean score0.659295,stdev=0.054013,epochs=169, mean epochs=197,time=0:29:29.71
# #53: score=0.621904,mean score0.658589,stdev=0.053742,epochs=145, mean epochs=196,time=0:25:25.92
# #54: score=0.704060,mean score0.659431,stdev=0.053594,epochs=154, mean epochs=195,time=0:27:27.70
# #55: score=0.563307,mean score0.657684,stdev=0.054635,epochs=251, mean epochs=196,time=0:43:43.59
# #56: score=0.601038,mean score0.656672,stdev=0.054663,epochs=226, mean epochs=197,time=0:39:39.10
# #57: score=0.627826,mean score0.656166,stdev=0.054313,epochs=212, mean epochs=197,time=0:37:37.57
# #58: score=0.725150,mean score0.657355,stdev=0.054587,epochs=159, mean epochs=196,time=0:28:28.46
# #59: score=0.676919,mean score0.657687,stdev=0.054181,epochs=219, mean epochs=197,time=0:38:38.51
# #60: score=0.606306,mean score0.656831,stdev=0.054129,epochs=240, mean epochs=197,time=0:42:42.38
# #61: score=0.669876,mean score0.657045,stdev=0.053709,epochs=211, mean epochs=198,time=0:36:36.86
# #62: score=0.664822,mean score0.657170,stdev=0.053283,epochs=202, mean epochs=198,time=0:35:35.46
# #63: score=0.606631,mean score0.656368,stdev=0.053234,epochs=248, mean epochs=198,time=0:43:43.22
# #64: score=0.633842,mean score0.656016,stdev=0.052891,epochs=184, mean epochs=198,time=0:32:32.03
# #65: score=0.755182,mean score0.657541,stdev=0.053883,epochs=194, mean epochs=198,time=0:34:34.05
# #66: score=0.626434,mean score0.657070,stdev=0.053608,epochs=222, mean epochs=199,time=0:40:40.43
# #67: score=0.645977,mean score0.656905,stdev=0.053223,epochs=182, mean epochs=198,time=0:36:36.50
# #68: score=0.620285,mean score0.656366,stdev=0.053014,epochs=202, mean epochs=198,time=0:40:40.94
# #69: score=0.611847,mean score0.655721,stdev=0.052897,epochs=170, mean epochs=198,time=0:36:36.30
# #70: score=0.654472,mean score0.655703,stdev=0.052518,epochs=170, mean epochs=197,time=0:35:35.10
# #71: score=0.647033,mean score0.655581,stdev=0.052157,epochs=144, mean epochs=197,time=0:30:30.16
# #72: score=0.610400,mean score0.654953,stdev=0.052062,epochs=190, mean epochs=197,time=0:36:36.30
# #73: score=0.691699,mean score0.655457,stdev=0.051881,epochs=168, mean epochs=196,time=0:33:33.44
# #74: score=0.713326,mean score0.656239,stdev=0.051960,epochs=142, mean epochs=195,time=0:27:27.87
# #75: score=0.620552,mean score0.655763,stdev=0.051775,epochs=174, mean epochs=195,time=0:33:33.48
# #76: score=0.636254,mean score0.655506,stdev=0.051481,epochs=186, mean epochs=195,time=0:35:35.54
# #77: score=0.652724,mean score0.655470,stdev=0.051147,epochs=184, mean epochs=195,time=0:36:36.26
# #78: score=0.728280,mean score0.656404,stdev=0.051474,epochs=192, mean epochs=195,time=0:39:39.07
# #79: score=0.611962,mean score0.655841,stdev=0.051387,epochs=175, mean epochs=195,time=0:36:36.24
# #80: score=0.568329,mean score0.654747,stdev=0.051983,epochs=198, mean epochs=195,time=0:43:43.37
# #81: score=0.720232,mean score0.655556,stdev=0.052164,epochs=154, mean epochs=194,time=0:35:35.82
# #82: score=0.722354,mean score0.656370,stdev=0.052361,epochs=154, mean epochs=194,time=0:27:27.49
# #83: score=0.640684,mean score0.656181,stdev=0.052073,epochs=289, mean epochs=195,time=0:51:51.62
# #84: score=0.569947,mean score0.655155,stdev=0.052600,epochs=220, mean epochs=195,time=0:42:42.92
# #85: score=0.596459,mean score0.654464,stdev=0.052671,epochs=251, mean epochs=196,time=0:45:45.48
# #86: score=0.593169,mean score0.653751,stdev=0.052775,epochs=247, mean epochs=196,time=0:42:42.53
# #87: score=0.584291,mean score0.652953,stdev=0.052991,epochs=244, mean epochs=197,time=0:45:45.45
# #88: score=0.684961,mean score0.653317,stdev=0.052798,epochs=244, mean epochs=197,time=0:43:43.17
# #89: score=0.688087,mean score0.653707,stdev=0.052628,epochs=184, mean epochs=197,time=0:33:33.01
# #90: score=0.581779,mean score0.652908,stdev=0.052875,epochs=183, mean epochs=197,time=0:33:33.06
# #91: score=0.569617,mean score0.651993,stdev=0.053296,epochs=306, mean epochs=198,time=0:53:53.41
# #92: score=0.721419,mean score0.652747,stdev=0.053492,epochs=147, mean epochs=198,time=0:27:27.06
# #93: score=0.653426,mean score0.652755,stdev=0.053204,epochs=229, mean epochs=198,time=0:40:40.71
# #94: score=0.719833,mean score0.653468,stdev=0.053366,epochs=141, mean epochs=197,time=0:25:25.38
# #95: score=0.670793,mean score0.653651,stdev=0.053113,epochs=246, mean epochs=198,time=0:43:43.05
# #96: score=0.673671,mean score0.653859,stdev=0.052875,epochs=194, mean epochs=198,time=0:33:33.83
# #97: score=0.701032,mean score0.654346,stdev=0.052817,epochs=211, mean epochs=198,time=0:38:38.62
# #98: score=0.608867,mean score0.653882,stdev=0.052746,epochs=255, mean epochs=199,time=0:44:44.79
# #99: score=0.662646,mean score0.653970,stdev=0.052486,epochs=205, mean epochs=199,time=0:35:35.72
# #100: score=0.671685,mean score0.654147,stdev=0.052252,epochs=152, mean epochs=198,time=0:26:26.89

# %%
time_took = time.time() - start_time
print(f"time={hms_string(time_took)}")
# Out:
# time=0:26:26.89
